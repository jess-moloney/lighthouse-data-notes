# %%
! pip install pandas mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python39\site-packages (1.5.0)
# Collecting mlxtend
#   Downloading mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 1.3/1.3 MB 874.2 kB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: setuptools in c:\program files\python39\lib\site-packages (from mlxtend) (58.1.0)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlxtend) (3.6.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from mlxtend) (1.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (4.37.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.21.0

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_excel('Online Retail.xlsx')
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %%
df[df.InvoiceNo.str.contains('C', na=False)].head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
df = df[~df['InvoiceNo'].str.contains('C')]

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
market_basket = df[df['Country'] =="United Kingdom"].groupby(
                ['InvoiceNo', 'Description'])['Quantity']

# %%
market_basket.head()
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541889    12
# 541890     8
# 541891    24
# 541892    24
# 541893    10
# Name: Quantity, Length: 486133, dtype: int64

# %%
market_basket = market_basket.sum().unstack().reset_index().fillna(0).set_index('InvoiceNo')

# %%
market_basket.head()
# Out:
# Description  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365         0.0                             0.0
# 536366         0.0                             0.0
# 536367         0.0                             0.0
# 536368         0.0                             0.0
# 536369         0.0                             0.0
#
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                  0.0                 0.0
# 536366                                  0.0                 0.0
# 536367                                  0.0                 0.0
# 536368                                  0.0                 0.0
# 536369                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                0.0                       0.0
# 536366                                0.0                       0.0
# 536367                                0.0                       0.0
# 536368                                0.0                       0.0
# 536369                                0.0                       0.0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                               0.0                       0.0
# 536366                               0.0                       0.0
# 536367                               0.0                       0.0
# 536368                               0.0                       0.0
# 536369                               0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                    0.0                      0.0  ...
# 536366                                    0.0                      0.0  ...
# 536367                                    0.0                      0.0  ...
# 536368                                    0.0                      0.0  ...
# 536369                                    0.0                      0.0  ...
#
# Description  wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# InvoiceNo
# 536365                       0.0                  0.0                  0.0
# 536366                       0.0                  0.0                  0.0
# 536367                       0.0                  0.0                  0.0
# 536368                       0.0                  0.0                  0.0
# 536369                       0.0                  0.0                  0.0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                  0.0                   0.0
# 536366                  0.0                   0.0
# 536367                  0.0                   0.0
# 536368                  0.0                   0.0
# 536369                  0.0                   0.0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                               0.0                           0.0
# 536366                               0.0                           0.0
# 536367                               0.0                           0.0
# 536368                               0.0                           0.0
# 536369                               0.0                           0.0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                0.0                   0.0
# 536366                                0.0                   0.0
# 536367                                0.0                   0.0
# 536368                                0.0                   0.0
# 536369                                0.0                   0.0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                     0.0
# 536366                     0.0
# 536367                     0.0
# 536368                     0.0
# 536369                     0.0
#
# [5 rows x 4188 columns]

# %%
def encode_data(datapoint):
    if datapoint <= 0:
        return 0
    if datapoint >= 1:
        return 1

# %%
market_basket = market_basket.applymap(encode_data)

# %%
market_basket.head()
# Out:
# Description  20713   4 PURPLE FLOCK DINNER CANDLES  \
# InvoiceNo
# 536365           0                               0
# 536366           0                               0
# 536367           0                               0
# 536368           0                               0
# 536369           0                               0
#
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536365                                    0                   0
# 536366                                    0                   0
# 536367                                    0                   0
# 536368                                    0                   0
# 536369                                    0                   0
#
# Description   I LOVE LONDON MINI BACKPACK   NINE DRAWER OFFICE TIDY  \
# InvoiceNo
# 536365                                  0                         0
# 536366                                  0                         0
# 536367                                  0                         0
# 536368                                  0                         0
# 536369                                  0                         0
#
# Description   OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536365                                 0                         0
# 536366                                 0                         0
# 536367                                 0                         0
# 536368                                 0                         0
# 536369                                 0                         0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# InvoiceNo                                                               ...
# 536365                                      0                        0  ...
# 536366                                      0                        0  ...
# 536367                                      0                        0  ...
# 536368                                      0                        0  ...
# 536369                                      0                        0  ...
#
# Description  wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# InvoiceNo
# 536365                         0                    0                    0
# 536366                         0                    0                    0
# 536367                         0                    0                    0
# 536368                         0                    0                    0
# 536369                         0                    0                    0
#
# Description  wrongly marked  wrongly marked 23343  \
# InvoiceNo
# 536365                    0                     0
# 536366                    0                     0
# 536367                    0                     0
# 536368                    0                     0
# 536369                    0                     0
#
# Description  wrongly marked carton 22804  wrongly marked. 23343 in box  \
# InvoiceNo
# 536365                                 0                             0
# 536366                                 0                             0
# 536367                                 0                             0
# 536368                                 0                             0
# 536369                                 0                             0
#
# Description  wrongly sold (22719) barcode  wrongly sold as sets  \
# InvoiceNo
# 536365                                  0                     0
# 536366                                  0                     0
# 536367                                  0                     0
# 536368                                  0                     0
# 536369                                  0                     0
#
# Description  wrongly sold sets
# InvoiceNo
# 536365                       0
# 536366                       0
# 536367                       0
# 536368                       0
# 536369                       0
#
# [5 rows x 4188 columns]

# %%
itemsets = apriori(market_basket, min_support=0.03, use_colnames=True)
# Out:
# C:\Users\User\AppData\Roaming\Python\Python39\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
rules = association_rules(itemsets, metric="lift", min_threshold=0.5)

# %%
rules
# Out:
#                             antecedents                          consequents  \
# 0           (ALARM CLOCK BAKELIKE RED )         (ALARM CLOCK BAKELIKE GREEN)
# 1          (ALARM CLOCK BAKELIKE GREEN)          (ALARM CLOCK BAKELIKE RED )
# 2     (GREEN REGENCY TEACUP AND SAUCER)     (PINK REGENCY TEACUP AND SAUCER)
# 3      (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 4    (ROSES REGENCY TEACUP AND SAUCER )    (GREEN REGENCY TEACUP AND SAUCER)
# 5     (GREEN REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER )
# 6      (JUMBO  BAG BAROQUE BLACK WHITE)            (JUMBO BAG RED RETROSPOT)
# 7             (JUMBO BAG RED RETROSPOT)     (JUMBO  BAG BAROQUE BLACK WHITE)
# 8             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 9             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 10            (JUMBO BAG RED RETROSPOT)  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 11  (JUMBO SHOPPER VINTAGE RED PAISLEY)            (JUMBO BAG RED RETROSPOT)
# 12            (JUMBO BAG RED RETROSPOT)             (JUMBO STORAGE BAG SUKI)
# 13             (JUMBO STORAGE BAG SUKI)            (JUMBO BAG RED RETROSPOT)
# 14            (LUNCH BAG  BLACK SKULL.)            (LUNCH BAG RED RETROSPOT)
# 15            (LUNCH BAG RED RETROSPOT)            (LUNCH BAG  BLACK SKULL.)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.049818            0.046925  0.030159    0.605376  12.900874
# 1             0.046925            0.049818  0.030159    0.642694  12.900874
# 2             0.050032            0.037658  0.030909    0.617773  16.404818
# 3             0.037658            0.050032  0.030909    0.820768  16.404818
# 4             0.051264            0.050032  0.037551    0.732497  14.640537
# 5             0.050032            0.051264  0.037551    0.750535  14.640537
# 6             0.048747            0.103814  0.030534    0.626374   6.033613
# 7             0.103814            0.048747  0.030534    0.294118   6.033613
# 8             0.062085            0.103814  0.042051    0.677308   6.524245
# 9             0.103814            0.062085  0.042051    0.405057   6.524245
# 10            0.103814            0.060692  0.035194    0.339009   5.585724
# 11            0.060692            0.103814  0.035194    0.579876   5.585724
# 12            0.103814            0.060531  0.037390    0.360165   5.950055
# 13            0.060531            0.103814  0.037390    0.617699   5.950055
# 14            0.065138            0.074566  0.032516    0.499178   6.694431
# 15            0.074566            0.065138  0.032516    0.436063   6.694431
#
#     leverage  conviction
# 0   0.027821    2.415149
# 1   0.027821    2.659296
# 2   0.029024    2.517724
# 3   0.029024    5.300218
# 4   0.034986    3.551247
# 5   0.034986    3.803087
# 6   0.025473    2.398615
# 7   0.025473    1.347609
# 8   0.035605    2.777218
# 9   0.035605    1.576478
# 10  0.028893    1.421061
# 11  0.028893    2.133149
# 12  0.031106    1.468299
# 13  0.031106    2.344190
# 14  0.027658    1.847829
# 15  0.027658    1.657742

# %% [markdown]
# # MBA without MLExtend (for very large datasets)

# %%
df_manual = df[df['Country'] =="United Kingdom"]

# %%
orders = df_manual.set_index('InvoiceNo')['StockCode']

# %%
orders.head()
# Out:
# InvoiceNo
# 536365    85123A
# 536365     71053
# 536365    84406B
# 536365    84029G
# 536365    84029E
# Name: StockCode, dtype: object

# %%
statistics = orders.value_counts().to_frame("frequency")
statistics['support']  = statistics / len(set(orders.index)) * 100
statistics
# Out:
#         frequency    support
# 85123A       2175  10.809065
# 85099B       1960   9.740582
# 22423        1714   8.518040
# 47566        1615   8.026041
# 20725        1421   7.061922
# ...           ...        ...
# 90025B          1   0.004970
# 85068           1   0.004970
# 90021           1   0.004970
# 84455           1   0.004970
# 23843           1   0.004970
#
# [4055 rows x 2 columns]

# %%
min_support=0.03 # same value we used above.
items_above_support = statistics[statistics['support'] >= min_support].index
orders_above_support = orders[orders.isin(items_above_support)]

# %%
order_counts = orders.index.value_counts()
orders_over_two_index = order_counts[order_counts>=2].index
orders_over_two = orders[orders.index.isin(orders_over_two_index)]

# %%
orders_over_two
# Out:
# InvoiceNo
# 536365    85123A
# 536365     71053
# 536365    84406B
# 536365    84029G
# 536365    84029E
#            ...
# 581585     22466
# 581586     22061
# 581586     23275
# 581586     21217
# 581586     20685
# Name: StockCode, Length: 484050, dtype: object

# %%
statistics = orders_over_two.value_counts().to_frame("frequency")
statistics['support']  = statistics / len(set(orders_over_two.index)) * 100

# %%
from itertools import combinations, groupby
from collections import Counter

# %%
def itemset_generator(orders):
    orders = orders.reset_index().values
    for order_id, order_object in groupby(orders, lambda x: x[0]):
        item_list = [item[1] for item in order_object]
        for item_pair in combinations(item_list, 2):
            yield item_pair
itemsets_gen = itemset_generator(orders_over_two)
itemsets  = pd.Series(Counter(itemsets_gen)).to_frame("frequencyAC")
itemsets['supportAC'] = itemsets['frequencyAC'] / len(orders_over_two_index) * 100
itemsets = itemsets[itemsets['supportAC'] >= min_support]

# %%
# Create table of association rules and compute relevant metrics
itemsets = itemsets.reset_index().rename(columns={'level_0': 'antecedents', 'level_1': 'consequents'})
itemsets = (itemsets
     .merge(statistics.rename(columns={'freq': 'freqA', 'support': 'antecedent support'}), left_on='antecedents', right_index=True)
     .merge(statistics.rename(columns={'freq': 'freqC', 'support': 'consequents support'}), left_on='consequents', right_index=True))

itemsets['confidenceAtoC'] = itemsets['supportAC'] / itemsets['antecedent support']
itemsets['confidenceCtoA'] = itemsets['supportAC'] / itemsets['consequents support']
itemsets['lift'] = itemsets['supportAC'] / (itemsets['antecedent support'] * itemsets['consequents support'])
itemsets=itemsets[['antecedents', 'consequents','antecedent support', 'consequents support', 'confidenceAtoC','lift']]

# %%
itemsets
# Out:
#         antecedents consequents  antecedent support  consequents support  \
# 0            85123A       71053           13.021148             2.018127
# 977900        71053       71053            2.018127             2.018127
# 995926       84406B       71053            1.631420             2.018127
# 204647       84029E       71053            2.549849             2.018127
# 204652        22752       71053            2.078550             2.018127
# ...             ...         ...                 ...                  ...
# 1685403       23575       23580            0.193353             0.138973
# 1685409       23576       23580            0.205438             0.138973
# 1683248       23535       23561            1.280967             0.078550
# 1683287       23562       23561            0.247734             0.078550
# 1682365       23429       23430            0.114804             0.084592
#
#          confidenceAtoC      lift
# 0              0.023202  0.011497
# 977900         0.050898  0.025221
# 995926         0.025926  0.012847
# 204647         0.011848  0.005871
# 204652         0.055233  0.027368
# ...                 ...       ...
# 1685403        0.218750  1.574049
# 1685409        0.205882  1.481458
# 1683248        0.023585  0.300254
# 1683287        0.121951  1.552533
# 1682365        0.263158  3.110902
#
# [1687361 rows x 6 columns]

# %%
rules = itemsets
rules_over_50 = rules[(rules.confidenceAtoC >0.50)]
rules_over_50.set_index('antecedents',inplace=True)
rules_over_50.reset_index(inplace=True)
rules_over_50=rules_over_50.sort_values('lift', ascending=False)

# %%
rules_over_50
# Out:
#      antecedents consequents  antecedent support  consequents support  \
# 1841      48173c      85099f            0.042296             0.060423
# 1881      90082D      90082B            0.036254             0.072508
# 1888       20698       20697            0.054381             0.078550
# 1281      90129D      90129E            0.042296             0.084592
# 1880      37444C      72051S            0.054381             0.084592
# ...          ...         ...                 ...                  ...
# 1152      35915C      85123A            0.356495            13.021148
# 1135      85039A      85123A            0.966767            13.021148
# 1145       85093      85123A            0.513595            13.021148
# 1151       84638      85123A            0.199396            13.021148
# 1146       22104      85123A            0.356495            13.021148
#
#       confidenceAtoC       lift
# 1841        0.714286  11.821429
# 1881        0.833333  11.493056
# 1888        0.888889  11.316239
# 1281        0.857143  10.132653
# 1880        0.666667   7.880952
# ...              ...        ...
# 1152        0.525424   0.040352
# 1135        0.518750   0.039839
# 1145        0.517647   0.039754
# 1151        0.515152   0.039563
# 1146        0.508475   0.039050
#
# [1889 rows x 6 columns]

# %%
rules_over_50 = pd.merge(rules_over_50, df_manual, how='left', left_on='antecedents', right_on='StockCode')

# %%
rules_over_50.head()
# Out:
#   antecedents consequents  antecedent support  consequents support  \
# 0      48173c      85099f            0.042296             0.060423
# 1      48173c      85099f            0.042296             0.060423
# 2      48173c      85099f            0.042296             0.060423
# 3      48173c      85099f            0.042296             0.060423
# 4      48173c      85099f            0.042296             0.060423
#
#    confidenceAtoC       lift InvoiceNo StockCode           Description  \
# 0        0.714286  11.821429    536982    48173c  DOORMAT BLACK FLOCK
# 1        0.714286  11.821429    537640    48173c  DOORMAT BLACK FLOCK
# 2        0.714286  11.821429    538351    48173c  DOORMAT BLACK FLOCK
# 3        0.714286  11.821429    538877    48173c  DOORMAT BLACK FLOCK
# 4        0.714286  11.821429    540832    48173c  DOORMAT BLACK FLOCK
#
#    Quantity         InvoiceDate  UnitPrice  CustomerID         Country
# 0         1 2010-12-03 14:27:00      16.98         NaN  United Kingdom
# 1         7 2010-12-07 15:31:00      16.98         NaN  United Kingdom
# 2         1 2010-12-10 15:17:00      16.98         NaN  United Kingdom
# 3         1 2010-12-14 15:29:00      16.98         NaN  United Kingdom
# 4         1 2011-01-11 14:42:00      16.63         NaN  United Kingdom

# %%
df_manual.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# rules_over_50['antecedents_description'] = rules_over_50.query(df_manual['StockCode']==rules_over_50['antecedents'])['antecedents'].map(df_manual['Description'])
# rules_over_50['consequents_description'] = rules_over_50.query(df_manual['StockCode']==rules_over_50['consequents'])['consequents'].map(df_manual['Description'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [117], line 1
# ----> 1 rules_over_50['antecedents_description'] = rules_over_50.query(df_manual['StockCode']==rules_over_50['antecedents'])['antecedents'].map(df_manual['Description'])
#       2 rules_over_50['consequents_description'] = rules_over_50.query(df_manual['StockCode']==rules_over_50['consequents'])['consequents'].map(df_manual['Description'])
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\arraylike.py:43, in OpsMixin.__eq__(self, other)
#      41 @unpack_zerodim_and_defer("__eq__")
#      42 def __eq__(self, other):
# ---> 43     return self._cmp_method(other, operator.eq)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\series.py:6240, in Series._cmp_method(self, other, op)
#    6237 res_name = ops.get_op_result_name(self, other)
#    6239 if isinstance(other, Series) and not self._indexed_same(other):
# -> 6240     raise ValueError("Can only compare identically-labeled Series objects")
#    6242 lvalues = self._values
#    6243 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#
# ValueError: Can only compare identically-labeled Series objects
